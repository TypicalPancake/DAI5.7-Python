# %% [markdown]
# # Importing Data set Departments.csv

# %% [markdown]
# # 1. Importing Libararies / Path

# %%
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\TypicalPancake\DA Instacart Basket Analysis 12-2024'

# %% [markdown]
# # 2. Importing Data

# %% [markdown]
# Orders Data

# %%
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders.csv'), index_col = False)

# %% [markdown]
# Products Data

# %%
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'products.csv'), index_col = False)

# %% [markdown]
# Departments Data

# %%
df_dep = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'departments.csv'), index_col = False)

# %% [markdown]
# # 3. Wrangling Data

# %% [markdown]
# Orders dataframe

# %%
df_ords=df_ords.drop(columns = ['eval_set'])

# %%
df_ords['order_id'] = df_ords['order_id'].astype('str')

# %%
df_ords['user_id'] = df_ords['user_id'].astype('str')

# %% [markdown]
# Department dataframe

# %%
df_dep_t=df_dep.T

# %%
df_dep.head()
# Out:
#   department_id       1      2       3        4        5              6  \
# 0    department  frozen  other  bakery  produce  alcohol  international
#
#            7     8                9  ...            12      13         14  \
# 0  beverages  pets  dry goods pasta  ...  meat seafood  pantry  breakfast
#
#              15          16         17      18      19    20       21
# 0  canned goods  dairy eggs  household  babies  snacks  deli  missing
#
# [1 rows x 22 columns]

# %%
df_ords.head()
# Out:
#   order_id user_id  order_number  order_dow  order_hour_of_day  \
# 0  2539329       1             1          2                  8
# 1  2398795       1             2          3                  7
# 2   473747       1             3          3                 12
# 3  2254736       1             4          4                  7
# 4   431534       1             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
df_dep.T
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
new_header = df_dep_t.iloc[0]

# %%
df_dep_t_new = df_dep_t[1:]

# %%
df_dep_t_new.columns = new_header

# %%
df_dep_t_new
# Out:
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %% [markdown]
# # 4. Creating Data Dictionary

# %%
data_dict = df_dep_t_new.to_dict('index')

# %%
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %% [markdown]
# # 5. Data Tasks

# %% [markdown]
# 4.4 Frequency for the busiest hour in placing orders

# %%
df_ords.describe()
# Out:
#        order_number     order_dow  order_hour_of_day  days_since_prior_order
# count  3.421083e+06  3.421083e+06       3.421083e+06            3.214874e+06
# mean   1.715486e+01  2.776219e+00       1.345202e+01            1.111484e+01
# std    1.773316e+01  2.046829e+00       4.226088e+00            9.206737e+00
# min    1.000000e+00  0.000000e+00       0.000000e+00            0.000000e+00
# 25%    5.000000e+00  1.000000e+00       1.000000e+01            4.000000e+00
# 50%    1.100000e+01  3.000000e+00       1.300000e+01            7.000000e+00
# 75%    2.300000e+01  5.000000e+00       1.600000e+01            1.500000e+01
# max    1.000000e+02  6.000000e+00       2.300000e+01            3.000000e+01

# %%
df_ords['order_number'] = df_ords['order_number'].astype('str')

# %%
df_ords.describe()
# Out:
#           order_dow  order_hour_of_day  days_since_prior_order
# count  3.421083e+06       3.421083e+06            3.214874e+06
# mean   2.776219e+00       1.345202e+01            1.111484e+01
# std    2.046829e+00       4.226088e+00            9.206737e+00
# min    0.000000e+00       0.000000e+00            0.000000e+00
# 25%    1.000000e+00       1.000000e+01            4.000000e+00
# 50%    3.000000e+00       1.300000e+01            7.000000e+00
# 75%    5.000000e+00       1.600000e+01            1.500000e+01
# max    6.000000e+00       2.300000e+01            3.000000e+01

# %%
df_ords.rename(columns = {'order_dow' : 'orders_day_of_the_week'}, inplace = False)
# Out:
#         order_id user_id order_number  orders_day_of_the_week  \
# 0        2539329       1            1                       2
# 1        2398795       1            2                       3
# 2         473747       1            3                       3
# 3        2254736       1            4                       4
# 4         431534       1            5                       4
# ...          ...     ...          ...                     ...
# 3421078  2266710  206209           10                       5
# 3421079  1854736  206209           11                       4
# 3421080   626363  206209           12                       1
# 3421081  2977660  206209           13                       1
# 3421082   272231  206209           14                       6
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# 1                        7                    15.0
# 2                       12                    21.0
# ...

# %%
df_ords['order_hour_of_day'].value_counts(dropna = True)
# Out:
# order_hour_of_day
# 10    288418
# 11    284728
# 15    283639
# 14    283042
# 13    277999
# 12    272841
# 16    272553
# 9     257812
# 17    228795
# 18    182912
# 8     178201
# 19    140569
# 20    104292
# 7      91868
# 21     78109
# 22     61468
# 23     40043
# 6      30529
# 0      22758
# 1      12398
# 5       9569
# 2       7539
# 4       5527
# 3       5474
# Name: count, dtype: int64

# %% [markdown]
# Busiest time are from 10 am - 11 am

# %% [markdown]
# 4.5 Department_id 4 what is it?

# %%
print(data_dict.get('4'))
# Out:
# {'department': 'produce'}

# %% [markdown]
# Department_id 4 is the produce category

# %% [markdown]
# 4.6 Create substet contatining breakfast item sales

# %%
df_prods_breakfast = df_prods.loc[df_prods['department_id'] == 14]

# %%
df_prods_breakfast.head()
# Out:
#      product_id                                      product_name  aisle_id  \
# 27           28                                 Wheat Chex Cereal       121
# 33           34                                               NaN       121
# 67           68                           Pancake Mix, Buttermilk       130
# 89           90                                      Smorz Cereal       121
# 210         211  Gluten Free Organic Cereal Coconut Maple Vanilla       130
#
#      department_id  prices
# 27              14    10.1
# 33              14    12.2
# 67              14    13.7
# 89              14     3.9
# 210             14     3.6

# %% [markdown]
# 4.7 Create dinner party subset w/ alcohol, deli, beverages, meat seafood.

# %%
df_prods_dinner_party = df_prods.loc[df_prods['department_id'].isin([5,7,12,20])]

# %%
df_prods_dinner_party
# Out:
#        product_id                                    product_name  aisle_id  \
# 2               3            Robust Golden Unsweetened Oolong Tea        94
# 6               7                  Pure Coconut Water With Orange        98
# 9              10  Sparkling Orange Juice & Prickly Pear Beverage       115
# 10             11                               Peach Mango Juice        31
# 16             17                               Rendered Duck Fat        35
# ...           ...                                             ...       ...
# 49676       49672                          Cafe Mocha K-Cup Packs        26
# 49679       49675             Cinnamon Dolce Keurig Brewed K Cups        26
# 49680       49676                          Ultra Red Energy Drink        64
# 49686       49682                              California Limeade        98
# 49688       49684       Vodka, Triple Distilled, Twist of Vanilla       124
#
#        department_id  prices
# ...

# %% [markdown]
# 4.8 How many rows are in the subset created?

# %%
df_prods_dinner_party.shape
# Out:
# (7650, 5)

# %% [markdown]
# 4.9 Cusomter with user_id 1. Need info

# %%
df_user1=df_ords.loc[df_ords['user_id'] == '1']

# %%
df_user1
# Out:
#    order_id user_id order_number  order_dow  order_hour_of_day  \
# 0   2539329       1            1          2                  8
# 1   2398795       1            2          3                  7
# 2    473747       1            3          3                 12
# 3   2254736       1            4          4                  7
# 4    431534       1            5          4                 15
# 5   3367565       1            6          2                  7
# 6    550135       1            7          1                  9
# 7   3108588       1            8          1                 14
# 8   2295261       1            9          1                 16
# 9   2550362       1           10          4                  8
# 10  1187899       1           11          4                  8
#
#     days_since_prior_order
# 0                      NaN
# 1                     15.0
# 2                     21.0
# 3                     29.0
# 4                     28.0
# 5                     19.0
# ...

# %%
df_user1.describe()
# Out:
#        order_dow  order_hour_of_day  days_since_prior_order
# count  11.000000          11.000000               10.000000
# mean    2.636364          10.090909               19.000000
# std     1.286291           3.477198                9.030811
# min     1.000000           7.000000                0.000000
# 25%     1.500000           7.500000               14.250000
# 50%     3.000000           8.000000               19.500000
# 75%     4.000000          13.000000               26.250000
# max     4.000000          16.000000               30.000000

# %% [markdown]
# 4.10 user_id 1 has bulk orders from Sunday - Wenesday around 10am on average. Always orders 19 days from each other and has never gone over 30 days without ordering.

# %%
df_ords.to_csv(os.path.join(path, '02 Data','Prepared Data', 'orders_wrangled.csv'))

# %%
df_dep_t_new.to_csv(os.path.join(path, '02 Data','Prepared Data', 'departments_wrangled.csv'))
