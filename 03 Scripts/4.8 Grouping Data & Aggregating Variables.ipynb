# %% [markdown]
# # 01. Import Libraries / Paths / Import Data

# %%
# import libraries
import pandas as pd
import numpy as np
import os

# %%
# creating path
path = r'C:\Users\TypicalPancake\DA Instacart Basket Analysis 12-2024'

# %%
# import dataframe
df_ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data' , 'Prepared Data' , 'orders_products_merged_derived.pkl'))

# %%
# previewing
df_ords_prods_merge.shape
df_ords_prods_merge.head(10)
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
# 5   2398795        1             2                   3                  7
# 6   2398795        1             2                   3                  7
# 7   2398795        1             2                   3                  7
# 8   2398795        1             2                   3                  7
# 9   2398795        1             2                   3                  7
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     NaN         196                  1          0   both
# ...

# %% [markdown]
# # 02. Aggregate Mean of 'order_number' & 'department_id' for Entire Dataframe

# %%
# grouping 'order_number' & 'department_id' & finding the mean
df_ords_prods_merge_sub=df_ords_prods_merge[:1000000]
df_ords_prods_merge_sub.groupby('department_id').agg({'order_number' : ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                14.800024
# 2                17.091743
# 3                17.913544
# 4                17.893092
# 5                15.214270
# 6                15.382135
# 7                17.694027
# 8                16.458105
# 9                15.957363
# 10               20.091818
# 11               16.482026
# 12               15.615061
# 13               16.484023
# 14               17.524632
# 15               15.691875
# 16               18.014071
# 17               16.150593
# 18               19.602850
# 19               17.631340
# 20               17.138607
# 21               21.956893

# %%
df_ords_prods_merge.groupby('department_id').agg({'order_number' : ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# # 03. Analyze Result

# %% [markdown]
# There are only 21 rows compared to 100000.
# The mean is different in each of the departments which shows there are more frequented departments compared to others.
# Putting this data into a histograms with the department names would be interesting to see.

# %% [markdown]
# # 04. Creating Loyalty Flag

# %%
# Aggregating Data 
df_ords_prods_merge['max_order'] = df_ords_prods_merge.groupby(['user_id'])['order_number'].transform('max')

# %%
df_ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both
#
# ...

# %%
# creating loyalty flag w/ loc function
df_ords_prods_merge.loc[df_ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
df_ords_prods_merge.loc[(df_ords_prods_merge['max_order'] <= 40) & (df_ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
df_ords_prods_merge.loc[df_ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# checking labels 
df_ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
# previewing dataframe
df_ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(50)
# Out:
#     user_id  loyalty_flag  order_number
# 0         1  New customer             1
# 1         1  New customer             1
# 2         1  New customer             1
# 3         1  New customer             1
# 4         1  New customer             1
# 5         1  New customer             2
# 6         1  New customer             2
# 7         1  New customer             2
# 8         1  New customer             2
# 9         1  New customer             2
# 10        1  New customer             2
# 11        1  New customer             3
# 12        1  New customer             3
# 13        1  New customer             3
# 14        1  New customer             3
# 15        1  New customer             3
# 16        1  New customer             4
# 17        1  New customer             4
# 18        1  New customer             4
# 19        1  New customer             4
# 20        1  New customer             4
# 21        1  New customer             5
# ...

# %% [markdown]
# # 05. Analyze Spending Habits for 3 Types of Customers Recently Created

# %%
# previewing loyalty category to analyze spending habits
df_ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max', 'std', 'median']})
# Out:
#                     prices
#                       mean  min   max       std median
# loyalty_flag
# Loyal customer    7.773487  1.0  25.0  4.205886    7.4
# New customer      7.801077  1.0  25.0  4.266452    7.4
# Regular customer  7.798145  1.0  25.0  4.254540    7.4

# %% [markdown]
# customers are very close in spending with loyal customers spending the least and the new customer spending the most with the regulars spending the middle tier.

# %% [markdown]
# # 06. Creating 'Low Spender' & 'High Spender'

# %%
# Aggregating data
df_ords_prods_merge['avg_product_price'] = df_ords_prods_merge.groupby(['user_id'])['prices'].transform('mean')

# %%
# previewing data
df_ords_prods_merge[['user_id', 'avg_product_price']].head(20)
# Out:
#     user_id  avg_product_price
# 0         1           6.367797
# 1         1           6.367797
# 2         1           6.367797
# 3         1           6.367797
# 4         1           6.367797
# 5         1           6.367797
# 6         1           6.367797
# 7         1           6.367797
# 8         1           6.367797
# 9         1           6.367797
# 10        1           6.367797
# 11        1           6.367797
# 12        1           6.367797
# 13        1           6.367797
# 14        1           6.367797
# 15        1           6.367797
# 16        1           6.367797
# 17        1           6.367797
# 18        1           6.367797
# 19        1           6.367797

# %%
# creating spender labels
df_ords_prods_merge.loc[df_ords_prods_merge['avg_product_price'] >= 10, 'spending_flag'] = 'High spender'
df_ords_prods_merge.loc[df_ords_prods_merge['avg_product_price'] < 10, 'spending_flag'] = 'Low spender'

# %%
# previewing
df_ords_prods_merge[['user_id', 'avg_product_price', 'spending_flag']].head(20)
# Out:
#     user_id  avg_product_price spending_flag
# 0         1           6.367797   Low spender
# 1         1           6.367797   Low spender
# 2         1           6.367797   Low spender
# 3         1           6.367797   Low spender
# 4         1           6.367797   Low spender
# 5         1           6.367797   Low spender
# 6         1           6.367797   Low spender
# 7         1           6.367797   Low spender
# 8         1           6.367797   Low spender
# 9         1           6.367797   Low spender
# 10        1           6.367797   Low spender
# 11        1           6.367797   Low spender
# 12        1           6.367797   Low spender
# 13        1           6.367797   Low spender
# 14        1           6.367797   Low spender
# 15        1           6.367797   Low spender
# 16        1           6.367797   Low spender
# 17        1           6.367797   Low spender
# 18        1           6.367797   Low spender
# 19        1           6.367797   Low spender

# %%
df_ords_prods_merge['spending_flag'].value_counts(dropna = False)
# Out:
# spending_flag
# Low spender     32285150
# High spender      119709
# Name: count, dtype: int64

# %% [markdown]
# # 07. Creating 'Order Frequency Flag'

# %%
# aggregating data
df_ords_prods_merge['median_days_between_orders'] = df_ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform('median')

# %%
# previewing
df_ords_prods_merge[['user_id', 'days_since_prior_order', 'median_days_between_orders']].head(15)
# Out:
#     user_id  days_since_prior_order  median_days_between_orders
# 0         1                     NaN                        20.5
# 1         1                     NaN                        20.5
# 2         1                     NaN                        20.5
# 3         1                     NaN                        20.5
# 4         1                     NaN                        20.5
# 5         1                    15.0                        20.5
# 6         1                    15.0                        20.5
# 7         1                    15.0                        20.5
# 8         1                    15.0                        20.5
# 9         1                    15.0                        20.5
# 10        1                    15.0                        20.5
# 11        1                    21.0                        20.5
# 12        1                    21.0                        20.5
# 13        1                    21.0                        20.5
# ...

# %%
# creating lables for frequency flag
df_ords_prods_merge.loc[df_ords_prods_merge['median_days_between_orders'] > 20, 'order_frequency_flag'] = 'Non-frequent customer'
df_ords_prods_merge.loc[(df_ords_prods_merge['median_days_between_orders'] <= 20) & (df_ords_prods_merge['median_days_between_orders'] > 10), 'order_frequency_flag'] = 'Regular customer'
df_ords_prods_merge.loc[df_ords_prods_merge['median_days_between_orders'] <= 10, 'order_frequency_flag'] = 'Frequent customer'

# %%
# previewing data
df_ords_prods_merge['order_frequency_flag'].value_counts(dropna = False)
# Out:
# order_frequency_flag
# Frequent customer        21559853
# Regular customer          7208564
# Non-frequent customer     3636437
# NaN                             5
# Name: count, dtype: int64

# %%
df_ords_prods_merge[['user_id', 'days_since_prior_order', 'median_days_between_orders', 'order_frequency_flag']].head(20)
# Out:
#     user_id  days_since_prior_order  median_days_between_orders  \
# 0         1                     NaN                        20.5
# 1         1                     NaN                        20.5
# 2         1                     NaN                        20.5
# 3         1                     NaN                        20.5
# 4         1                     NaN                        20.5
# 5         1                    15.0                        20.5
# 6         1                    15.0                        20.5
# 7         1                    15.0                        20.5
# 8         1                    15.0                        20.5
# 9         1                    15.0                        20.5
# 10        1                    15.0                        20.5
# 11        1                    21.0                        20.5
# 12        1                    21.0                        20.5
# 13        1                    21.0                        20.5
# ...

# %% [markdown]
# # 08. Clean & Export Dataframe as pickle

# %%
df_ords_prods_merge.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_grouped.pkl'))
